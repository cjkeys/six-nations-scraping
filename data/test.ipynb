# %%
import pandas as pd

# %%
pd.read_csv("six_nations_stats2.csv")
# Out:
#      Assists  Attacking scrum win  Average points  Breakdown steal      Club  \
# 0        NaN                  7.0            31.0              NaN    France
# 1        NaN                  7.0            30.0              NaN    France
# 2        NaN                  6.0            44.0              1.0     Italy
# 3        NaN                  6.0            31.0              NaN     Italy
# 4        NaN                  5.0            50.0              NaN   England
# ..       ...                  ...             ...              ...       ...
# 224      NaN                  NaN             NaN              NaN   Ireland
# 225      NaN                  NaN             NaN              NaN  Scotland
# 226      NaN                  NaN             NaN              NaN  Scotland
# 227      NaN                  NaN             NaN              NaN     Wales
# 228      NaN                  NaN             NaN              NaN     Wales
#
# ...

# %%
_df = pd.read_csv("six_nations_stats.csv")

# %%
_df.head()
# Out:
#    Assists  Attacking scrum win  Breakdown steal     Club  Conceded penalty  \
# 0      NaN                  7.0              NaN   France               NaN
# 1      NaN                  7.0              NaN   France               NaN
# 2      NaN                  6.0              1.0    Italy               1.0
# 3      NaN                  6.0              NaN    Italy               1.0
# 4      NaN                  5.0              NaN  England               1.0
#
#    Conversion  Defenders beaten  Drop goal      ID  Kick 50-22  ...  Offloads  \
# 0         NaN               3.0        NaN  244767         NaN  ...       1.0
# 1         NaN               1.0        NaN  175065         NaN  ...       2.0
# 2         NaN               4.0        NaN  197335         NaN  ...       1.0
# 3         NaN               NaN        NaN  208272         NaN  ...       NaN
# 4         NaN               3.0        NaN  209612         NaN  ...       1.0
#
# ...
